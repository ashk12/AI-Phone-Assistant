# %%
import json
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import google.generativeai as genai
import os
import re
from dotenv import load_dotenv

load_dotenv('.env.local')

class MultiIntentPhoneSystem:
    def __init__(self, json_file_path: str):
        self.products = self.load_products(json_file_path)
        self.setup_gemini()
        self.create_vector_store()
        
    def setup_gemini(self):
        api_key = os.getenv('GEMINI_API_KEY')
        genai.configure(api_key=api_key)
        self.model = genai.GenerativeModel('gemini-2.0-flash')
    
    def load_products(self, file_path: str):
        with open(file_path, 'r', encoding='utf-8') as file:
            return json.load(file)
    
    def create_product_context(self, product: dict) -> str:
        """Create rich context for each product"""
        features = ", ".join(product.get('features', []))
        return f"""
        {product['brand']} {product['name']} - ₹{product['price']}
        • Camera: {product['camera']}MP
        • Battery: {product['battery']}mAh with {product['charging']}W charging
        • RAM: {product['ram']}GB
        • Screen: {product['screen_size']} inches
        • OS: {product['os']}
        • Features: {features}
        """
    
    def create_vector_store(self):
        """Create semantic search index"""
        self.documents = []
        for product in self.products:
            self.documents.append(self.create_product_context(product))
        
        self.vectorizer = TfidfVectorizer(stop_words='english', max_features=1000)
        self.document_vectors = self.vectorizer.fit_transform(self.documents)
    
    def detect_intent(self, query: str) -> dict:
        """Detect user intent and extract parameters"""
        prompt = f"""
        Analyze this phone query and classify intent with parameters:
        Query: "{query}"
        
        Return JSON with:
        {{
            "intent": "recommendation" | "comparison" | "explanation" | "details",
            "confidence": 0.0-1.0,
            "parameters": {{
                "max_price": number or null,
                "min_price": number or null,
                "brand": string or null,
                "min_camera": number or null,
                "min_battery": number or null, 
                "min_charging": number or null,
                "os": string or null,
                "max_screen_size": number or null,
                "phone_names": array of strings,  // for comparison/details
                "concept": string or null  // for explanation
            }},
            "query_type": "structured" | "semantic"  // numeric vs conceptual
        }}
        
        Intent Guidelines:
        - recommendation: Asking for phone suggestions
        - comparison: Comparing 2+ specific phones (vs, versus, compare)
        - explanation: Explaining technical concepts (what is, explain, vs in concepts)
        - details: Getting info about specific phone (tell me about, details of)
        
        Return only JSON.
        """
        
        try:
            response = self.model.generate_content(prompt)
            if hasattr(response, "text") and response.text:
                raw_text = response.text.strip()
            elif hasattr(response, "candidates") and response.candidates:
                raw_text = response.candidates[0].content.parts[0].text.strip()
            else:
                # print("Gemini returned an unexpected format.")
                return None
            raw_text = re.sub(r"^```json\s*", "", raw_text)
            raw_text = re.sub(r"```$", "", raw_text).strip()
            # print("Gemini raw output:", raw_text)
            try:
                intent_data = json.loads(raw_text)
                return intent_data
            except json.JSONDecodeError:
                print("Response not valid JSON. Returning raw text.")
                return {"intent": "unknown", "confidence": 0.0, "raw_text": raw_text}
                # return json.loads(response.text.strip())
        except Exception as e:
            print(f"Intent detection error: {e}")
            return {"intent": "recommendation", "confidence": 0.7, "parameters": {}}
    
    def structured_search(self, filters: dict) -> list:
        """Exact filtering for numeric queries"""
        results = self.products.copy()
        
        if filters.get('max_price'):
            results = [p for p in results if p['price'] <= filters['max_price']]
        if filters.get('min_price'):
            results = [p for p in results if p['price'] >= filters['min_price']]
        if filters.get('brand'):
            brand = filters['brand'].lower()
            results = [p for p in results if brand in p['brand'].lower()]
        if filters.get('min_camera'):
            results = [p for p in results if p['camera'] >= filters['min_camera']]
        if filters.get('min_battery'):
            results = [p for p in results if p['battery'] >= filters['min_battery']]
        if filters.get('min_charging'):
            results = [p for p in results if p['charging'] >= filters['min_charging']]
        if filters.get('os'):
            os_filter = filters['os'].lower()
            results = [p for p in results if os_filter in p['os'].lower()]
        if filters.get('max_screen_size'):
            results = [p for p in results if p['screen_size'] <= filters['max_screen_size']]
            
        return results
    
    def semantic_search(self, query: str, top_k: int = 5) -> list:
        """Semantic search for conceptual queries"""
        query_vector = self.vectorizer.transform([query])
        similarities = cosine_similarity(query_vector, self.document_vectors).flatten()
        
        top_indices = np.argsort(similarities)[-top_k:][::-1]
        results = []
        for idx in top_indices:
            if similarities[idx] > 0.1:
                results.append({
                    'product': self.products[idx],
                    'score': similarities[idx]
                })
        return results
    
    def find_phones_by_name(self, phone_names: list) -> list:
        """Find specific phones by name matching"""
        found_phones = []
        for name in phone_names:
            name_lower = name.lower()
            for product in self.products:
                if name_lower in product['name'].lower() or name_lower in product['brand'].lower():
                    found_phones.append(product)
                    break
        return found_phones
    
    
    def handle_recommendation(self, query: str, intent_data: dict) -> str:
        """Handle phone recommendation requests"""
        print("Handling: RECOMMENDATION")
        
        filters = intent_data['parameters']
        query_type = intent_data.get('query_type', 'semantic')
        
        if query_type == 'structured':
            # Use exact filtering for numeric queries
            results = self.structured_search(filters)
            results = [{'product': p, 'score': 1.0} for p in results]
        else:
            # Use semantic search for conceptual queries
            results = self.semantic_search(query, top_k=8)
            
            # Apply filters to semantic results
            if filters:
                filtered_results = []
                for result in results:
                    product = result['product']
                    if self.apply_filters(product, filters):
                        filtered_results.append(result)
                results = filtered_results
        
        if not results:
            return "No phones found matching your criteria. Try adjusting your requirements."
        
        context = "Available phones matching your query:\n\n"
        for i, result in enumerate(results[:6]):
            product = result['product']
            context += f"{i+1}. {product['name']} - ₹{product['price']:,}\n"
            context += f"   Camera: {product['camera']}MP | Battery: {product['battery']}mAh | "
            context += f"Charging: {product['charging']}W | RAM: {product['ram']}GB\n"
            context += f"   Features: {', '.join(product.get('features', []))}\n\n"
        
        prompt = f"""
        User wants phone recommendations: "{query}"
        
        {context}
        
        Provide a helpful, structured recommendation:
        
        **Best Options for You:**
        [Brief summary of why these match their needs]
        
        **Top Recommendations:**
        [Ranked list with 2-4 best options]
        
        For each phone:
        - **Key Strengths:** [What makes it good for their specific needs]
        - **Spec Highlights:** [Most relevant specs for their query]
        - **Considerations:** [Any trade-offs or things to note]
        
        **Decision Guide:** [Brief comparison of key differences between options]
        
        **Final Advice:** [1-2 sentence summary recommendation]
        
        Be specific and focus on how each phone addresses their stated needs.
        """
        
        try:
            response = self.model.generate_content(prompt)
            return response.text
        except Exception as e:
            return f"Here are phones matching your criteria:\n{context}"
    
    def handle_comparison(self, query: str, intent_data: dict) -> str:
        """Handle phone comparison requests"""
        print("Handling: COMPARISON")
        
        phone_names = intent_data['parameters'].get('phone_names', [])
        
        if len(phone_names) < 2:
            return "Please specify at least two phones to compare (e.g., 'Compare Phone A vs Phone B')."
        phones_to_compare = self.find_phones_by_name(phone_names)
        
        if len(phones_to_compare) < 2:
            found_names = [p['name'] for p in phones_to_compare]
            return f"Could not find both phones. Found: {', '.join(found_names) if found_names else 'None'}"
        comparison_data = []
        for phone in phones_to_compare:
            comparison_data.append({
                'name': phone['name'],
                'price': phone['price'],
                'camera': phone['camera'],
                'battery': phone['battery'],
                'charging': phone['charging'],
                'ram': phone['ram'],
                'screen_size': phone['screen_size'],
                'os': phone['os'],
                'features': phone.get('features', [])
            })
        
        context = json.dumps(comparison_data, indent=2)
        
        prompt = f"""
        User wants to compare phones: "{query}"
        
        Phones to compare:
        {context}
        
        Provide a detailed comparison:
        
        **Comparison: {phones_to_compare[0]['name']} vs {phones_to_compare[1]['name']}**
        
        **Specifications Comparison:**
        | Feature | {phones_to_compare[0]['name']} | {phones_to_compare[1]['name']} |
        |---------|----------------|----------------|
        | Price | ₹{phones_to_compare[0]['price']:,} | ₹{phones_to_compare[1]['price']:,} |
        | Camera | {phones_to_compare[0]['camera']}MP | {phones_to_compare[1]['camera']}MP |
        | Battery | {phones_to_compare[0]['battery']}mAh | {phones_to_compare[1]['battery']}mAh |
        | Charging | {phones_to_compare[0]['charging']}W | {phones_to_compare[1]['charging']}W |
        | RAM | {phones_to_compare[0]['ram']}GB | {phones_to_compare[1]['ram']}GB |
        | Screen Size | {phones_to_compare[0]['screen_size']}" | {phones_to_compare[1]['screen_size']}" |
        | OS | {phones_to_compare[0]['os']} | {phones_to_compare[1]['os']} |
        
        **Key Differences:**
        [Highlight 3-4 most significant differences]
        
        **Recommendation:**
        - Choose {phones_to_compare[0]['name']} if: [2-3 specific reasons]
        - Choose {phones_to_compare[1]['name']} if: [2-3 specific reasons]
        
        **Verdict:** [Which is better for different use cases]
        """
        
        try:
            response = self.model.generate_content(prompt)
            return response.text
        except Exception as e:
            response = f"**Comparison: {phones_to_compare[0]['name']} vs {phones_to_compare[1]['name']}**\n\n"
            for phone in phones_to_compare:
                response += f"**{phone['name']}** - ₹{phone['price']:,}\n"
                response += f"• Camera: {phone['camera']}MP | Battery: {phone['battery']}mAh\n"
                response += f"• Charging: {phone['charging']}W | RAM: {phone['ram']}GB\n\n"
            return response
    
    def handle_explanation(self, query: str, intent_data: dict) -> str:
        """Handle technical explanation requests"""
        print("Handling: EXPLANATION")
        
        concept = intent_data['parameters'].get('concept', '')
        
        prompt = f"""
        User wants explanation: "{query}"
        
        Explain this mobile phone concept in simple, clear terms:
        Concept: {concept or query}
        
        Provide a comprehensive explanation:
        
        **What is {concept or 'this'}?**
        [Simple definition]
        
        **How it works:**
        [Brief technical explanation in layman's terms]
        
        **Why it matters in phones:**
        [Practical benefits and impact on user experience]
        
        **Key Things to Know:**
        [3-5 important points or comparisons]
        
        **Real-world Example:**
        [How this affects phone usage or buying decisions]
        
        Keep it educational but easy to understand for non-technical users.
        Use analogies if helpful.
        """
        
        try:
            response = self.model.generate_content(prompt)
            return response.text
        except Exception as e:
            return f"I can explain '{concept or query}'. This feature relates to phone capabilities and user experience. For detailed technical explanations, please rephrase your question."
    
    def handle_details(self, query: str, intent_data: dict) -> str:
        """Handle detailed information requests about specific phones"""
        print("Handling: DETAILS")
        
        phone_names = intent_data['parameters'].get('phone_names', [])
        
        if not phone_names:
            return "Please specify which phone you want details about (e.g., 'Tell me about iPhone 15')."
        
        phones = self.find_phones_by_name(phone_names)
        
        if not phones:
            return f"Sorry, I couldn't find information about '{phone_names[0]}'. Please check the phone name and try again."
        
        phone = phones[0]  
        
        prompt = f"""
        User wants detailed information about: "{query}"
        
        Phone Details:
        {json.dumps(phone, indent=2)}
        
        Provide comprehensive details in this format:
        
        **{phone['name']} - Complete Overview**
        
        **Key Specifications:**
        • **Price:** ₹{phone['price']:,}
        • **Camera:** {phone['camera']}MP rear camera
        • **Battery:** {phone['battery']}mAh with {phone['charging']}W fast charging
        • **Performance:** {phone['ram']}GB RAM, {phone['os']} OS
        • **Display:** {phone['screen_size']} inch screen
        
        **Features & Capabilities:**
        {chr(10).join(['• ' + feature for feature in phone.get('features', [])])}
        
        **Detailed Analysis:**
        [Provide insights about camera quality, performance, battery life, display quality, etc.]
        
        **Best For:**
        [What type of users would benefit most from this phone]
        
        **Considerations:**
        [Any limitations or things to know before buying]
        
        **Verdict:** [Overall assessment of the phone's value and positioning]
        
        Make it informative and helpful for someone considering this phone.
        """
        
        try:
            response = self.model.generate_content(prompt)
            return response.text
        except Exception as e:
            # Fallback to basic details
            response = f"**{phone['name']} - Details**\n\n"
            response += f"**Price:** ₹{phone['price']:,}\n"
            response += f"**Camera:** {phone['camera']}MP\n"
            response += f"**Battery:** {phone['battery']}mAh with {phone['charging']}W charging\n"
            response += f"**RAM:** {phone['ram']}GB\n"
            response += f"**Screen:** {phone['screen_size']} inches\n"
            response += f"**OS:** {phone['os']}\n"
            response += f"**Features:** {', '.join(phone.get('features', []))}\n"
            return response
    
    def apply_filters(self, product: dict, filters: dict) -> bool:
        """Helper to apply filters to a product"""
        if filters.get('max_price') and product['price'] > filters['max_price']:
            return False
        if filters.get('min_price') and product['price'] < filters['min_price']:
            return False
        if filters.get('brand') and filters['brand'].lower() not in product['brand'].lower():
            return False
        if filters.get('min_camera') and product['camera'] < filters['min_camera']:
            return False
        if filters.get('min_battery') and product['battery'] < filters['min_battery']:
            return False
        if filters.get('min_charging') and product['charging'] < filters['min_charging']:
            return False
        if filters.get('os') and filters['os'].lower() not in product['os'].lower():
            return False
        if filters.get('max_screen_size') and product['screen_size'] > filters['max_screen_size']:
            return False
        return True
    
    def process_query(self, query: str) -> str:
        """Main method to process any type of query"""
        print(f"\nProcessing: '{query}'")
        
        # Step 1: Detect intent
        intent_data = self.detect_intent(query)
        intent = intent_data.get('intent', 'recommendation')
        confidence = intent_data.get('confidence', 0.7)
        
        print(f"Detected intent: {intent} (confidence: {confidence})")
        
        # Step 2: Route to appropriate handler
        if intent == 'comparison':
            return self.handle_comparison(query, intent_data)
        elif intent == 'explanation':
            return self.handle_explanation(query, intent_data)
        elif intent == 'details':
            return self.handle_details(query, intent_data)
        else:  # recommendation (default)
            return self.handle_recommendation(query, intent_data)

def main():
    system = MultiIntentPhoneSystem("./app/data/products.json")
    
    test_queries = [
        # Recommendation queries
        "Best camera phone under ₹30,000?",
        "Compact Android with good one-hand use",
        "Battery king with fast charging, around ₹25k",
        "Phones with great gaming performance under 35000",
        
        # Comparison queries
        "Compare Nothing Phone 1 vs OnePlus Nord 2T 5G",
        "Pixel 8a vs OnePlus 12R which is better?",
        "Samsung Galaxy S23 vs iPhone 14",
        
        # Explanation queries
        "Explain OIS vs EIS",
        "What is fast charging and how does it work?",
        "Difference between AMOLED and LCD displays",
        
        # Details queries
        "Tell me more about Nothing Phone 1",
        "Details of OnePlus Nord 2T 5G",
        "What are the specs of Samsung Galaxy S23?",
        
        # Mixed/ambiguous
        "Show me Samsung phones only, under ₹25k",
        "I like this phone, tell me more details"
    ]
    
    for query in test_queries:
        print(f"\n{'='*80}")
        print(f"QUERY: {query}")
        print(f"{'='*80}")
        response = system.process_query(query)
        print(response)
        print(f"{'='*80}")

if __name__ == "__main__":
    main()
# Out:
# ================================================================================
# QUERY: Best camera phone under ₹30,000?
# ================================================================================
#
# Processing: 'Best camera phone under ₹30,000?'
# Detected intent: recommendation (confidence: 0.95)
# Handling: RECOMMENDATION
# Okay, here's a phone recommendation tailored to your request for the best camera phone under ₹30,000, based on the provided options:
#
# **Best Options for You:**
#
# You're looking for the best camera, so we'll prioritize phones with the highest megapixel counts and those that combine good image sensors with other important features like fast charging and sufficient RAM for smooth operation.
#
# **Top Recommendations:**
#
# 1.  **Xiaomi Redmi Note 12 Pro Plus - ₹29,999**
# 2.  **Realme 10 Pro Plus - ₹24,999**
# 3.  **OnePlus Nord CE 2 Lite 5G - ₹19,989**
#
# **Xiaomi Redmi Note 12 Pro Plus**
#
# *   **Key Strengths:** This phone boasts the highest megapixel count of the group, giving you potentially more detailed images, especially in good lighting. Super fast charging.
# *   **Spec Highlights:**
#     *   Camera: 200.0MP
#     *   Charging: 120.0W
#     *   RAM: 8.0GB
# *   **Considerations:** It's the most expensive on the list, stretching your budget to its limit. Battery is slightly smaller than other phones on the list, but the fast charging more than makes up for this.
#
# **Realme 10 Pro Plus**
#
# *   **Key Strengths:** A good balance of camera quality, fast charging, and price. Its 108MP camera should deliver detailed photos.
# *   **Spec Highlights:**
#     *   Camera: 108.0MP
#     *   Charging: 67.0W
#     *   RAM: 6.0GB
# *   **Considerations:** While the camera is good, it has a smaller megapixel count than the Xiaomi Redmi Note 12 Pro Plus.
#
# **OnePlus Nord CE 2 Lite 5G**
#
# *   **Key Strengths:** The most affordable on the list.
# *   **Spec Highlights:**
#     *   Camera: 64.0MP
#     *   Charging: 33.0W
#     *   RAM: 6.0GB
# *   **Considerations:** While the megapixel count is higher than some of the other cheaper phones on the list, it does not compare to the top two contenders.
#
# **Decision Guide:**
#
# *   **Camera Quality:** If camera quality is paramount and you're willing to spend the most, the Xiaomi Redmi Note 12 Pro Plus is the clear winner due to its 200MP camera.
# *   **Value for Money:** The Realme 10 Pro Plus strikes a good balance between price and performance, offering a decent camera and fast charging.
# *   **Budget:** The OnePlus Nord CE 2 Lite 5G is the most affordable option but has less of a focus on camera.
#
# **Final Advice:**
#
# If you want the absolute best camera within your budget, get the Xiaomi Redmi Note 12 Pro Plus. If you want to save some money, go with the Realme 10 Pro Plus.
#
# ================================================================================
#
# ================================================================================
# QUERY: Compact Android with good one-hand use
# ================================================================================
#
# Processing: 'Compact Android with good one-hand use'
# Detected intent: recommendation (confidence: 0.9)
# Handling: RECOMMENDATION
# Okay, here's a recommendation based on the user's request for a compact Android phone with good one-hand use, considering the available Vivo Y100:
#
# **Best Options for You:**
#
# The Vivo Y100 is a good contender if you're looking for a manageable Android phone with 5G, but its actual size is key to deciding if it truly fits your one-hand use preference.
#
# **Top Recommendations:**
#
# 1.  **Vivo Y100 - ₹29,990**
#
#     *   **Key Strengths:** This phone offers a good balance of features for the price. The 5G connectivity ensures future-proofing, and the fast charging is a huge convenience. The camera is decent, and the battery life should be solid.
#     *   **Spec Highlights:**
#         *   50.0MP Camera
#         *   5000.0mAh Battery
#         *   66.0W Charging
#         *   5G Connectivity
#     *   **Considerations:** Whether it's truly compact enough for *your* definition of one-hand use is crucial. Check the dimensions against what you consider comfortable. Other phones might be even smaller.
#
# **Decision Guide:**
#
# The Vivo Y100 is a solid choice for a well-rounded phone but may not be the absolute smallest available.
#
# **Final Advice:**
#
# The Vivo Y100 is a good phone overall. Determine if the physical size suits your one-hand use needs before deciding.
#
# ================================================================================
#
# ================================================================================
# QUERY: Battery king with fast charging, around ₹25k
# ================================================================================
#
# Processing: 'Battery king with fast charging, around ₹25k'
# Detected intent: recommendation (confidence: 0.9)
# Handling: RECOMMENDATION
# Okay, here's a structured phone recommendation based on the user's request for a "Battery king with fast charging, around ₹25k" and the provided phone list.
#
# **Best Options for You:**
#
# Based on your need for a phone with excellent battery life and fast charging around ₹25,000, the Realme phones listed stand out. They offer large battery capacities and decent fast charging capabilities at significantly lower prices than your stated budget, which is a bonus! The Vivo Y12a isn't considered a strong option due to its unknown charging specs.
#
# **Top Recommendations:**
#
# 1.  **Realme 10**
# 2.  **Realme 8**
#
# For each phone:
#
# *   **Realme 10**
#
#     *   **Key Strengths:**  A good balance of battery life, fast charging, and a modern design, all at a very affordable price. Its 33W charging is reasonably quick.
#     *   **Spec Highlights:** Battery: 5000mAh, Charging: 33W
#     *   **Considerations:** While the camera is decent, it's not a flagship-level performer. Consider if the camera is as important as battery/charging speed. RAM is on the lower side, but extended memory can help.
#
# *   **Realme 8**
#
#     *   **Key Strengths:**  Slightly faster charging than the Realme 10.
#     *   **Spec Highlights:** Battery: 5000mAh, Charging: 30W
#     *   **Considerations:** Very similar in performance to the Realme 10, but may be harder to find in stock depending on your location. The charging speed difference is minimal. RAM is on the lower side, but extended memory can help.
#
# **Decision Guide:**
#
# *   **Charging Speed:** The Realme 10 has 33W charging.
# *   **Overall Balance:** Both offer a very similar experience, the Realme 10 is generally the better value and easier to find.
#
# **Final Advice:**
#
# Given your budget and preferences, the Realme 10 is the most recommended option. However, consider whether the camera specs are good enough for you compared to other models with faster charging speeds, and bigger batteries.
#
# ================================================================================
#
# ================================================================================
# QUERY: Phones with great gaming performance under 35000
# ================================================================================
#
# Processing: 'Phones with great gaming performance under 35000'
# Detected intent: recommendation (confidence: 0.95)
# Handling: RECOMMENDATION
# No phones found matching your criteria. Try adjusting your requirements.
# ================================================================================
#
# ================================================================================
# QUERY: Compare Nothing Phone 1 vs OnePlus Nord 2T 5G
# ================================================================================
#
# Processing: 'Compare Nothing Phone 1 vs OnePlus Nord 2T 5G'
# Detected intent: comparison (confidence: 0.95)
# Handling: COMPARISON
# **Comparison: Nothing Phone 1 vs OnePlus Nord 2T 5G**
#
# **Specifications Comparison:**
#
# | Feature       | Nothing Phone 1 | OnePlus Nord 2T 5G |
# |---------------|----------------|--------------------|
# | Price         | ₹26,749          | ₹28,999             |
# | Camera        | 50.0MP          | 50.0MP             |
# | Battery       | 4500.0mAh       | 4500.0mAh          |
# | Charging      | 33.0W           | 80.0W              |
# | RAM           | 8.0GB           | 8.0GB              |
# | Screen Size   | 6.55"           | 6.43"              |
# | OS            | android         | android            |
#
# **Key Differences:**
#
# *   **Price:** The Nothing Phone 1 is noticeably cheaper at ₹26,749 compared to the OnePlus Nord 2T 5G at ₹28,999.
# *   **Charging Speed:** The OnePlus Nord 2T 5G offers significantly faster charging at 80.0W, compared to the Nothing Phone 1's 33.0W.
# *   **Screen Size:** The Nothing Phone 1 has a slightly larger screen at 6.55" compared to the OnePlus Nord 2T 5G's 6.43".
#
# **Recommendation:**
#
# *   **Choose Nothing Phone 1 if:**
#     *   You want to save money.
#     *   You prefer a slightly larger screen.
#     *   You appreciate a unique design aesthetic (Glyph Interface).
#
# *   **Choose OnePlus Nord 2T 5G if:**
#     *   Fast charging is a priority.
#     *   You prefer a slightly more compact phone.
#     *   You value the OnePlus OxygenOS experience.
#
# **Verdict:**
#
# The **OnePlus Nord 2T 5G** is better for users who prioritize extremely fast charging and a slightly more compact form factor, even if it means paying a bit more. The **Nothing Phone 1** is a great option for those who are budget-conscious and appreciate a larger screen with a unique and eye-catching design. Both phones offer a similar core experience in terms of camera performance and processing power with 8GB RAM, so the decision comes down to charging speed, price, and personal design preferences.
#
# ================================================================================
#
# ================================================================================
# QUERY: Pixel 8a vs OnePlus 12R which is better?
# ================================================================================
#
# Processing: 'Pixel 8a vs OnePlus 12R which is better?'
# Detected intent: comparison (confidence: 0.95)
# Handling: COMPARISON
# Could not find both phones. Found: None
# ================================================================================
#
# ================================================================================
# QUERY: Samsung Galaxy S23 vs iPhone 14
# ================================================================================
#
# Processing: 'Samsung Galaxy S23 vs iPhone 14'
# Detected intent: comparison (confidence: 0.95)
# Handling: COMPARISON
# **Comparison: Samsung Galaxy S23 Ultra 5G vs Apple iPhone 14**
#
# **Specifications Comparison:**
# | Feature | Samsung Galaxy S23 Ultra 5G | Apple iPhone 14 |
# |---------|----------------|----------------|
# | Price | ₹114,990 | ₹65,999 |
# | Camera | 200.0MP | 12.0MP |
# | Battery | 5000.0mAh | 3279.0mAh |
# | Charging | 45.0W | nanW |
# | RAM | 8.0GB | 6.0GB |
# | Screen Size | 6.8" | 6.1" |
# | OS | android | ios |
#
# **Key Differences:**
#
# *   **Camera:** The Samsung Galaxy S23 Ultra 5G boasts a significantly higher resolution 200.0MP camera compared to the iPhone 14's 12.0MP camera.
# *   **Price:** The Apple iPhone 14 is considerably cheaper than the Samsung Galaxy S23 Ultra 5G.
# *   **Battery:** The Samsung Galaxy S23 Ultra 5G has a larger battery capacity (5000.0mAh) compared to the Apple iPhone 14 (3279.0mAh).
# *   **Operating System:** The Samsung Galaxy S23 Ultra 5G runs on Android, while the Apple iPhone 14 runs on iOS.
#
# **Recommendation:**
#
# *   **Choose Samsung Galaxy S23 Ultra 5G if:**
#     *   You prioritize camera quality and want the best possible photo and video capabilities.
#     *   You need a long-lasting battery and faster charging speeds.
#     *   You prefer the Android operating system and its customization options.
# *   **Choose Apple iPhone 14 if:**
#     *   You are on a budget and looking for a more affordable option.
#     *   You prefer the simplicity and user-friendliness of the iOS ecosystem.
#     *   You want a more compact phone with a smaller screen size.
#
# **Verdict:**
#
# *   For photography enthusiasts and users who value battery life, the **Samsung Galaxy S23 Ultra 5G** is the better choice due to its superior camera and larger battery.
# *   For users looking for a more affordable and user-friendly smartphone with a compact design, the **Apple iPhone 14** is a solid option.
#
# ================================================================================
#
# ================================================================================
# QUERY: Explain OIS vs EIS
# ================================================================================
#
# Processing: 'Explain OIS vs EIS'
# Detected intent: explanation (confidence: 0.95)
# Handling: EXPLANATION
# Okay, here's an explanation of OIS vs EIS, designed to be clear and understandable for non-technical users:
#
# **What is OIS vs EIS?**
#
# *   **OIS (Optical Image Stabilization):** Think of OIS as tiny, built-in shock absorbers for your phone's camera lens or sensor. It physically counteracts hand movements, keeping the image steady.
# *   **EIS (Electronic Image Stabilization):** EIS is like a digital video editor working in real-time. It uses software to analyze the video and digitally compensate for shaking.
#
# **How it works:**
#
# *   **OIS:** Inside the camera, tiny motors and gyroscopes detect movement. They then move the lens or the sensor itself in the opposite direction to counteract that movement. Imagine balancing a glass of water on a tray – OIS is like subtly tilting the tray to keep the water from spilling when you're walking.
# *   **EIS:** The phone's processor looks at the video feed and identifies shaky movements. It then crops the image slightly and shifts it around to smooth out the video.  Think of it like cropping a photo and moving it slightly to center the subject. Because it crops, you lose a bit of the overall image area.
#
# **Why it matters in phones:**
#
# *   **OIS:**
#     *   **Sharper photos in low light:** Because the camera can stay open longer without blurring the image due to hand shake, you get brighter, clearer pictures in dim conditions.
#     *   **Smoother videos:** Reduces shakiness in videos, making them look more professional and less amateurish.
# *   **EIS:**
#     *   **Smoother videos (especially with a wide field of view):** Works well for video recording, making footage less shaky, especially when you're moving around.
#     *   **Cost-effective:** EIS is cheaper to implement than OIS because it only relies on software.
#
# **Key Things to Know:**
#
# 1.  **OIS is generally better for still photos, especially in low light.** It physically stabilizes the image, resulting in less blur.
# 2.  **EIS relies on cropping, so you lose some of the image quality or field of view.** The software makes up the difference.
# 3.  **OIS is more expensive to implement,** which is why you usually find it on higher-end phones.
# 4.  **Many phones use both OIS and EIS together for even better stabilization.** OIS handles the major movements, while EIS fine-tunes the result.
# 5.  **EIS can sometimes produce a "warped" or artificial-looking video**, especially with sudden or extreme movements, because the software is working hard to compensate.
#
# **Real-world Example:**
#
# Imagine you're at a concert, trying to take a picture of your favorite band in the dimly lit venue.
#
# *   **Without OIS or EIS:** The photo is likely to be blurry due to your shaky hands and the low light.
# *   **With OIS:** The photo will be much sharper and brighter because the camera can keep the lens open longer without blurring.
# *   **With EIS (for a video):** The video you record will be noticeably less shaky than if you didn't have any stabilization. However, if you zoom in too much or move around wildly, you might notice some warping or a loss of clarity.
#
# So, when you're considering a phone purchase, pay attention to whether it has OIS, EIS, or both. OIS is generally a better sign of a higher-quality camera system, particularly if you take a lot of photos in low light. EIS is a great addition for video recording and can still significantly improve your results. Understanding the difference can help you choose a phone that best suits your photography and videography needs.
#
# ================================================================================
#
# ================================================================================
# QUERY: What is fast charging and how does it work?
# ================================================================================
#
# Processing: 'What is fast charging and how does it work?'
# Detected intent: explanation (confidence: 0.95)
# Handling: EXPLANATION
# Okay, here's a simple explanation of fast charging for mobile phones:
#
# **What is fast charging?**
#
# Fast charging is like giving your phone a super-charged energy boost.  Instead of slowly trickling power into your battery, it fills it up much quicker, getting you back up and running faster.  Think of it like filling a glass with a firehose versus a small tap - the firehose is the fast charger.
#
# **How it works:**
#
# Normally, your phone charger sends electricity into your battery at a consistent rate (measured in Amps and Volts). Fast charging works by temporarily increasing the amount of power (Amps and/or Volts) pushed into your phone battery.  Your phone's charging circuitry and battery are specifically designed to handle this higher power flow safely. Think of it like a controlled pressure system. Your phone communicates with the charger to figure out how much power it can safely take. It then carefully adjusts the voltage and amperage to get the fastest possible charge without overheating or damaging the battery. This usually involves the charger briefly pushing higher voltage or current into the battery at the beginning of the charging cycle, then gradually tapering it down as the battery fills up to protect the battery.
#
# **Why it matters in phones:**
#
# Imagine you only have 15 minutes before you have to leave the house and your phone is almost dead. With a normal charger, you might only get a few percent charge, which isn't enough.  With fast charging, you could potentially get a significant charge (maybe 30-50% or more) in that same 15 minutes, giving you enough juice to last for several hours.  It's all about convenience, letting you quickly top up your battery during short breaks instead of being tethered to a charger for hours.  It makes a big difference in your daily use of your phone, allowing you to be more productive or enjoy entertainment on the go.
#
# **Key Things to Know:**
#
# *   **Not all chargers are created equal:** Just because a charger has a USB-C port doesn't mean it's a fast charger. Look for specific standards (like USB Power Delivery or Quick Charge) mentioned on both your phone and the charger.
# *   **Your phone needs to support it:**  Fast charging only works if your phone is designed to handle it.  A fast charger plugged into an older phone will only charge at the phone's standard charging speed.
# *   **Battery Health:** Fast charging does generate more heat, which can impact battery lifespan over a long time. Most phones manage heat very well, but avoid leaving your phone in direct sunlight while charging to prolong your battery's lifespan. Some phones even reduce charging speed automatically when the battery gets too hot.
# *   **Watts (W) matter:** The Wattage (W) is a measure of total power delivery. Generally, the higher the wattage, the faster the charging (e.g., a 65W charger is typically faster than a 25W charger).
# *   **It's fastest at the start:** Fast charging is usually fastest at the beginning (0-50% charge) and then slows down as the battery gets closer to full capacity. This is to protect the battery from damage.
#
# **Real-world Example:**
#
# Let's say you're running late for a meeting and notice your phone is at 10% battery.  Without fast charging, plugging it in for 10 minutes might only get you to 15%, barely enough to send a few emails.  But with fast charging, that same 10 minutes could boost your battery to 40%, giving you enough power for the entire meeting and your commute home. When you're shopping for a new phone, consider fast charging speeds a key factor. Does it support the latest standard? Is the charger included, or will you need to buy it separately? Knowing the fast charging capabilities can affect your purchase decision.
#
# ================================================================================
#
# ================================================================================
# QUERY: Difference between AMOLED and LCD displays
# ================================================================================
#
# Processing: 'Difference between AMOLED and LCD displays'
# Detected intent: explanation (confidence: 0.95)
# Handling: EXPLANATION
# Okay, here's an explanation of AMOLED and LCD displays, tailored for non-technical users, using the format you requested:
#
# **What are AMOLED and LCD displays?**
#
# *   **LCD (Liquid Crystal Display):** Think of it like a sandwich. It has a backlight (like a tiny light bulb) shining through a screen filled with liquid crystals. These crystals twist and turn to block or allow light to pass through, creating the images you see.  It's the older, more established technology.
# *   **AMOLED (Active Matrix Organic Light Emitting Diode):** Imagine each pixel on the screen as its own tiny light bulb. Each one can turn on and off independently. This means no backlight is needed. AMOLED is newer and generally more vibrant.
#
# **How it works:**
#
# *   **LCD:** A backlight shines white light through a polarizer (a filter that only allows light waves to pass through in a certain direction). This polarized light then goes through liquid crystals.  These crystals can be controlled by electricity to twist, affecting how much light gets through a color filter (red, green, blue) before reaching your eyes.
# *   **AMOLED:** Each pixel is made up of a tiny OLED (Organic Light Emitting Diode) that produces its own light when electricity is applied.  Different materials are used to create red, green, and blue light. Because each pixel generates its own light, the phone can turn off individual pixels completely to create true blacks.
#
# **Why it matters in phones:**
#
# *   **Picture Quality:** AMOLED displays generally offer more vibrant colors, better contrast (the difference between the brightest whites and the darkest blacks), and deeper blacks. This makes images and videos look more visually appealing. LCDs can still look good, but they usually don't reach the same levels of vibrancy or contrast.
# *   **Battery Life:** Because AMOLED screens can turn off individual pixels (especially when displaying black), they often use less power than LCD screens, particularly when using dark mode or viewing content with a lot of black.
# *   **Viewing Angles:** AMOLED screens tend to maintain their color and brightness even when viewed from an angle. LCD screens can sometimes look washed out or have their colors shift when viewed at an angle.
# *   **Thickness:** AMOLED displays are typically thinner than LCD displays because they don't need a backlight. This allows phone manufacturers to make slimmer devices.
#
# **Key Things to Know:**
#
# 1.  **Black is Black (er):** AMOLED displays can produce true black because they can completely turn off individual pixels.  LCDs can only block the backlight, which often results in a grayish-black.
# 2.  **Color Accuracy vs. Vibrancy:** While AMOLEDs are known for vibrant colors, some argue that LCDs can be more color-accurate (closer to real-world colors).  However, AMOLED technology is improving in color accuracy.
# 3.  **Brightness Levels:** LCD screens have traditionally been able to achieve higher peak brightness levels, which can be an advantage in direct sunlight. Newer AMOLED displays are catching up in this area.
# 4.  **Burn-In (Historically):** Older AMOLED screens were susceptible to "burn-in," where static elements (like navigation buttons) could leave a faint ghost image on the screen over time. This is much less of a problem with modern AMOLED technology.
#
# **Real-world Example:**
#
# Imagine you're watching a dark movie scene on your phone.
#
# *   **On an LCD phone:** The blacks in the scene might look grayish, and you might see some light bleeding around the edges of the screen.
# *   **On an AMOLED phone:** The blacks will be truly black, making the contrast much better and the picture more immersive. The battery drains more slowly.
#
# When you're shopping for a phone, understanding these differences can help you choose a device that best suits your needs and preferences. If you prioritize vibrant visuals, deep blacks, and potentially better battery life, an AMOLED display might be the way to go. If you prefer potentially more color-accurate images and higher brightness and maybe a lower upfront cost, an LCD screen might be a good fit. Ultimately, it comes down to personal preference and how you use your phone.
#
# ================================================================================
#
# ================================================================================
# QUERY: Tell me more about Nothing Phone 1
# ================================================================================
#
# Processing: 'Tell me more about Nothing Phone 1'
# Detected intent: details (confidence: 0.95)
# Handling: DETAILS
# **Nothing Phone 1 - Complete Overview**
#
# The Nothing Phone 1 is a mid-range smartphone that aims to stand out with its unique design, transparent back, and Glyph Interface. It offers a clean software experience and capable hardware for everyday use.
#
# **Key Specifications:**
# • **Price:** ₹26,749
# • **Camera:** 50.0MP rear camera
# • **Battery:** 4500.0mAh with 33.0W fast charging
# • **Performance:** 8.0GB RAM, Android OS
# • **Display:** 6.55 inch screen
#
# **Features & Capabilities:**
# • has 5g
# • has nfc
#
# **Detailed Analysis:**
#
# *   **Camera:** The 50MP rear camera is expected to deliver good quality images in various lighting conditions. While the megapixel count isn't everything, combined with proper image processing, it should provide detailed photos suitable for social media and everyday memories. Expect decent low-light performance.
# *   **Performance:** The 8GB of RAM paired with a capable processor (unspecified in the data, but generally a mid-range Snapdragon or similar) should ensure smooth multitasking and app performance for most users. Android OS provides a clean and optimized experience.
# *   **Battery Life:** The 4500mAh battery capacity is adequate for a full day of moderate use. The 33W fast charging support allows for reasonably quick top-ups, minimizing downtime.
# *   **Display:** The 6.55-inch screen size offers a good balance between screen real estate and comfortable handling.
#
# **Best For:**
#
# *   Users who prioritize design and aesthetics and want a phone that stands out from the crowd.
# *   Individuals who appreciate a clean and bloatware-free Android experience.
# *   Users who need 5G connectivity for faster data speeds.
# *   Tech enthusiasts who like innovative features like the Glyph Interface.
# *   Users who are okay with a mid-range camera system that provides good quality photos.
#
# **Considerations:**
#
# *   The data doesn't specify the processor. Research the specific chipset to understand the phone's gaming and heavy application performance.
# *   While the Glyph Interface is visually appealing, evaluate if it adds practical value to your daily usage or is purely aesthetic.
# *   Consider the long-term software support. Nothing is a relatively new brand, so understanding their commitment to software updates is important.
# *   Evaluate if the camera's performance meets your specific photography needs. Check reviews and sample images to get a better understanding.
#
# **Verdict:**
#
# The Nothing Phone 1 presents a compelling option for users seeking a stylish and functional mid-range smartphone. Its unique design, clean software, and 5G connectivity make it an attractive choice. However, potential buyers should carefully consider the processor capabilities, long-term software support, and camera performance to ensure it aligns with their specific needs and expectations. If aesthetics and a clean user experience are high priorities, the Nothing Phone 1 is definitely worth considering.
#
# ================================================================================
#
# ================================================================================
# QUERY: Details of OnePlus Nord 2T 5G
# ================================================================================
#
# Processing: 'Details of OnePlus Nord 2T 5G'
# Detected intent: details (confidence: 0.95)
# Handling: DETAILS
# **OnePlus Nord 2T 5G - Complete Overview**
#
# **Key Specifications:**
# *   **Price:** ₹28,999
# *   **Camera:** 50.0MP rear camera
# *   **Battery:** 4500.0mAh with 80.0W fast charging
# *   **Performance:** 8.0GB RAM, Android OS
# *   **Display:** 6.43 inch screen
#
# **Features & Capabilities:**
# *   Has 5G connectivity for faster download and streaming speeds.
# *   Has NFC (Near Field Communication) for contactless payments and easy device pairing.
#
# **Detailed Analysis:**
#
# *   **Camera Quality:** The 50.0MP rear camera should deliver good image quality, especially in well-lit conditions. It's likely to offer features like optical image stabilization (OIS) or electronic image stabilization (EIS) for smoother videos and sharper photos. Expect decent low-light performance as well. The camera setup details are not fully provided so the capabilities and additional sensors are unknown.
#
# *   **Performance:** The combination of 8.0GB RAM and Android OS delivers smooth multitasking and a responsive user experience for most apps and tasks. Details about the specific processor are missing, therefore a deep insight can not be given.
#
# *   **Battery Life:** The 4500.0mAh battery should provide all-day battery life for moderate usage. More intensive use (gaming, video streaming) will likely require charging before the day is over.
#
# *   **Charging:** The standout feature here is the 80.0W fast charging. This is a very fast charging speed, and it should allow you to quickly top up the battery from zero to 100% in a short amount of time (likely around 30 minutes).
#
# *   **Display Quality:** The 6.43-inch screen size is a good balance for comfortable viewing and one-handed use. Without details like panel type (AMOLED/LCD) or refresh rate, it's difficult to assess the display quality.
#
# **Best For:**
#
# *   Users who want a well-rounded smartphone with a good camera, fast charging, and decent performance.
# *   Those who value features like 5G connectivity and NFC.
# *   Android users looking for a smooth and responsive user experience.
# *   Users on a budget.
#
# **Considerations:**
#
# *   Without details of the processor used, it's difficult to assess its gaming capabilities.
# *   While the camera is a decent resolution, without knowing the sensor size and other lenses, its full capabilities cannot be determined.
# *   The provided data doesn't indicate the screen resolution or refresh rate.
# *   If you need a waterproof phone, this may not be the one for you, as there is no mention of IP rating.
# *   Consider the absence of expandable storage if you need a lot of local storage.
#
# **Verdict:**
#
# The OnePlus Nord 2T 5G appears to be a well-rounded mid-range smartphone with a focus on fast charging and a good camera. It is positioned as a value-for-money device, offering a combination of key features at an affordable price point. If the screen quality and processor are decent, the Nord 2T 5G could be a strong contender in its price range. A hands-on review is crucial before buying to get a complete idea about the device.
#
# ================================================================================
#
# ================================================================================
# QUERY: What are the specs of Samsung Galaxy S23?
# ================================================================================
#
# Processing: 'What are the specs of Samsung Galaxy S23?'
# Detected intent: details (confidence: 0.95)
# Handling: DETAILS
# Okay, here's a comprehensive overview of the Samsung Galaxy S23 Ultra 5G based on the provided data, formatted as requested:
#
# **Samsung Galaxy S23 Ultra 5G - Complete Overview**
#
# **Key Specifications:**
# *   **Price:** ₹114,990
# *   **Camera:** 200.0MP rear camera
# *   **Battery:** 5000.0mAh with 45.0W fast charging
# *   **Performance:** 8.0GB RAM, Android OS
# *   **Display:** 6.8 inch screen
#
# **Features & Capabilities:**
# *   Has 5G
# *   Has NFC
#
# **Detailed Analysis:**
#
# *   **Camera:** The 200MP rear camera is a standout feature, promising exceptional detail and clarity in photos and videos. Expect excellent low-light performance and the ability to crop and zoom extensively without significant loss of quality. This points towards top-tier image quality and advanced features like 8K video recording.
# *   **Performance:** The 8GB of RAM coupled with the Android OS suggests smooth multitasking and responsive performance for everyday tasks, demanding applications, and gaming. While the specific processor isn't mentioned, the phone's flagship status implies a high-end chipset capable of handling intensive workloads.
# *   **Battery:** The 5000mAh battery capacity should provide all-day battery life for most users. The 45W fast charging capability allows for relatively quick replenishment of the battery, minimizing downtime.
# *   **Display:** The 6.8-inch screen size suggests a large, immersive display, likely with a high resolution and refresh rate. Expect vibrant colors, sharp details, and smooth visuals for an enhanced viewing experience for multimedia, gaming, and general usage.
#
# **Best For:**
# *   **Photography enthusiasts:** The high-resolution camera is a major selling point, making this phone ideal for users who prioritize image quality and enjoy taking photos and videos.
# *   **Power users:** Those who require a phone capable of handling demanding tasks, multitasking, and running resource-intensive applications will appreciate the performance capabilities.
# *   **Content consumers:** The large, high-quality display makes it an excellent choice for watching videos, playing games, and browsing the web.
# *   **Users who need long battery life:** The 5000mAh battery will easily last a full day of heavy usage.
#
# **Considerations:**
#
# *   **Price:** The ₹114,990 price tag puts it in the premium category, making it a significant investment.
# *   **Size:** The 6.8-inch display may make it unwieldy for users with smaller hands or those who prefer a more compact device.
# *   **8GB RAM Model:** While sufficient for many tasks, some users might find the 8GB RAM configuration limiting for extremely heavy multitasking or future-proofing, especially considering that some flagship phones come with more RAM.
#
# **Verdict:**
#
# The Samsung Galaxy S23 Ultra 5G (with the specifications provided) is a powerhouse flagship device with a focus on camera performance, battery life, and a large, immersive display. It's best suited for users who demand the best in mobile technology and are willing to pay a premium for it. However, potential buyers should consider the size and price before making a purchase and weigh whether the benefits justify the cost compared to other high-end smartphones. Although 8GB RAM may be a concern for some, it should still offer excellent performance for most users.
#
# ================================================================================
#
# ================================================================================
# QUERY: Show me Samsung phones only, under ₹25k
# ================================================================================
#
# Processing: 'Show me Samsung phones only, under ₹25k'
# Intent detection error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 527.002945ms. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
# }
# ]
# Detected intent: recommendation (confidence: 0.7)
# Handling: RECOMMENDATION
# Okay, here's a structured recommendation for Samsung phones under ₹25,000 based on the provided list:
#
# **Best Options for You:**
#
# You're looking for a Samsung phone under ₹25,000. Based on your budget, we've focused on models that provide a good balance of features and affordability. The Samsung Galaxy S21 Ultra is not included due to being greatly outside the set price constraint.
#
# **Top Recommendations:**
#
# 1.  Samsung Galaxy A23
# 2.  Samsung Galaxy A15
# 3.  Samsung Galaxy M13 5G
# 4.  Samsung Galaxy A12
#
# **Phone Details:**
#
# *   **Samsung Galaxy A23 - ₹18,499**
#
#     *   **Key Strengths:** Fast charging compared to other phones, good camera.
#     *   **Spec Highlights:** 50MP Camera, 5000mAh Battery, 25W Charging, 6GB RAM.
#     *   **Considerations:** While the camera is good, it might not be a huge leap over other options.
#
# *   **Samsung Galaxy A15 - ₹15,990**
#
#     *   **Key Strengths:** Good balance of price and features, decent RAM for multitasking.
#     *   **Spec Highlights:** 48MP Camera, 5000mAh Battery, 6GB RAM.
#     *   **Considerations:** Charging speed unspecified, slower than the A23.
#
# *   **Samsung Galaxy M13 5G - ₹13,999**
#
#     *   **Key Strengths:** Affordable, 5G connectivity.
#     *   **Spec Highlights:** 50MP Camera, 5000mAh Battery, 6GB RAM, 5G.
#     *   **Considerations:** 15W Charging is slower.
#
# *   **Samsung Galaxy A12 - ₹11,999**
#
#     *   **Key Strengths:** Very Affordable.
#     *   **Spec Highlights:** 48MP Camera, 5000mAh Battery, 4GB RAM.
#     *   **Considerations:** 15W Charging is slower, only 4gb of RAM.
#
# **Decision Guide:**
#
# *   **Charging Speed:** If faster charging is important, the A23 (25W) is the best choice.
# *   **5G:** If you need 5G connectivity, the M13 5G is your only option.
# *   **RAM:** A15, A23, and M13 have 6GB of RAM. If you plan to multi-task, these will be better options.
# *   **Budget:** All options are under ₹20,000
#
# **Final Advice:**
#
# If you want the best overall experience for the price, go for the Samsung Galaxy A23 due to its good specs and fast charging. If you need 5G on a budget, choose the Galaxy M13 5G.
#
# ================================================================================
#
# ================================================================================
# QUERY: I like this phone, tell me more details
# ================================================================================
#
# Processing: 'I like this phone, tell me more details'
# Intent detection error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 55.658992123s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
# Detected intent: recommendation (confidence: 0.7)
# Handling: RECOMMENDATION
# Here are phones matching your criteria:
# Available phones matching your query:
#
# 1. Nothing Phone 1 (8GB RAM + 256GB) - ₹28,249
#    Camera: 50.0MP | Battery: 4500.0mAh | Charging: 33.0W | RAM: 8.0GB
#    Features: has 5g, has nfc
#
# 2. Nothing Phone 2 - ₹39,990
#    Camera: 50.0MP | Battery: 4700.0mAh | Charging: 66.0W | RAM: 8.0GB
#    Features: has 5g, has nfc
#
# 3. Nothing Phone 1 Lite - ₹24,990
#    Camera: 50.0MP | Battery: 5000.0mAh | Charging: 33.0W | RAM: 6.0GB
#    Features: has 5g, has nfc
#
# 4. Nothing Phone 1 - ₹26,749
#    Camera: 50.0MP | Battery: 4500.0mAh | Charging: 33.0W | RAM: 8.0GB
#    Features: has 5g, has nfc
#
# 5. Nothing Phone 1 (12GB RAM + 256GB) - ₹35,999
#    Camera: 50.0MP | Battery: 4500.0mAh | Charging: 33.0W | RAM: 12.0GB
#    Features: has 5g, has nfc
#
# 6. Cola Phone - ₹14,999
#    Camera: 50.0MP | Battery: 5000.0mAh | Charging: 33.0W | RAM: 4.0GB
#    Features: extended memory available
#
#
# ================================================================================
